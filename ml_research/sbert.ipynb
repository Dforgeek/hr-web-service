# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('resume_data.csv')
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
 pd.read_csv('resume_data.csv').shape
# Out:
# (4880, 21)

# %%
print(df.shape)
# Out:
# (4854, 21)

# %%
job_description = """
Позиция: Системный администратор.
Обязательны знания и опыт работы с серверными операционными системами Windows Server и Linux.
Умение настраивать сетевое оборудование.
Нужен аналитический склад ума. Не стоит нам писать, если вы не готовы целый день сидеть за компьютером.
Опыт работы с системами виртуализации и облачными сервисами.
Работа с базами данных и системами резервного копирования.
"""
labels = {
    'Position': 'Позиция:',
    'Specializations': 'Специализации:',
    'Previous_Positions': 'Предыдущие позиции:',
    'About_Me': 'Обо мне:',
    'Skills': 'Навыки:'
}

text_columns = ['Position', 'Specializations', 'Previous_Positions', 'About_Me', 'Skills']

resume_texts = df[text_columns].fillna('').apply(lambda x: '. '.join([f"{labels[col]} {x[col]}" for col in text_columns if x[col].strip() != '']), axis=1).tolist()

# %%
from nltk import word_tokenize
def clean_text(text):
    # Replace unwanted character sequences with a space or nothing
    text = text.replace("\n", " ").replace("\uf0d8", "")

    # Additional cleaning can be done here as needed

    return text.strip()

# Assuming resume_texts is a list of combined text entries
resume_texts = [clean_text(text) for text in resume_texts]

# %%
from transformers import AutoTokenizer, AutoModel
import torch

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask




device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#Load AutoModel from huggingface model repository
tokenizer = AutoTokenizer.from_pretrained("ai-forever/sbert_large_mt_nlu_ru")
model = AutoModel.from_pretrained("ai-forever/sbert_large_mt_nlu_ru")

model.to(device)
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(120138, 1024, padding_idx=0)
#     (position_embeddings): Embedding(512, 1024)
#     (token_type_embeddings): Embedding(2, 1024)
#     (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-23): 24 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=1024, out_features=1024, bias=True)
#             (key): Linear(in_features=1024, out_features=1024, bias=True)
#             (value): Linear(in_features=1024, out_features=1024, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=4096, out_features=1024, bias=True)
#           (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
torch.cuda.empty_cache()

# %%
def get_embeddings(sentences):
    encoded_input = tokenizer(sentences, padding=True, truncation=True, max_length=512, return_tensors='pt').to(device)
    #Compute token embeddings

    with torch.no_grad():
        model_output = model(**encoded_input)
    #Perform pooling. In this case, mean pooling
    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
    return sentence_embeddings

# %%
test = get_embeddings(job_description)

# %%
test.size()
# Out:
# torch.Size([1, 1024])

# %%
tests = []
tests.append(test)

# %%
tests.append(test)

# %%
dict(enumerate(tests))
# Out:
# {0: tensor([[ 0.0316,  0.2082, -0.6679,  ...,  0.5201,  0.0377, -0.2673]],
#         device='cuda:0'),
#  1: tensor([[ 0.0316,  0.2082, -0.6679,  ...,  0.5201,  0.0377, -0.2673]],
#         device='cuda:0')}

# %%
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm


class TextDataset(Dataset):
    def __init__(self, text_list):
      self.text_list = text_list

    def __len__(self):
      return len(self.text_list)

    def __getitem__(self, idx):
      return self.text_list[idx]

dataset = TextDataset(resume_texts)
dataloader = DataLoader(dataset, batch_size=128, shuffle=False)
embeddings = torch.empty(0, 1024).to(device)
with torch.no_grad():
  for batch in tqdm(dataloader, desc="Processing batches"):
    batch_embeddings = get_embeddings(batch)
    embeddings = torch.cat((embeddings, batch_embeddings), dim=0)

print(embeddings.size())
# Out:
# Processing batches: 100%|██████████| 38/38 [08:19<00:00, 13.14s/it]
# torch.Size([4854, 1024])

# %%
job_description = """
Вакансия
Название должности: Программист C# (Middle/Senior)
Основные задачи:
1. Разработка и поддержка корпоративных приложений на платформе .NET с использованием C#;
2. Взаимодействие с командой для создания качественного и масштабируемого кода;
3. Анализ требований к продукту и разработка технических решений;
4. Проведение код-ревью и оптимизация существующего кода;
5. Участие в проектировании архитектуры проектов.

Требования к кандидату:

1. Опыт работы с C# и .NET Framework/.NET Core не менее 3 лет;
2. Знание принципов ООП, SOLID, DRY, KISS;
3. Опыт работы с базами данных (SQL и NoSQL);
4. Навыки работы с Git;
5. Опыт разработки многопоточных приложений;
6. Умение писать юнит-тесты и понимание принципов TDD;
7. Хорошие коммуникативные навыки и способность работать в команде;
8. Владение английским языком на уровне не ниже Intermediate.
"""
vacancy_embedding = get_embeddings([job_description])

# %%
from torch import cosine_similarity

cosine_similarities= cosine_similarity(vacancy_embedding, embeddings).flatten()

resume_similarities_tfidf = dict(enumerate(cosine_similarities))

sorted_resume_similarities = sorted(resume_similarities_tfidf.items(), key=lambda item: item[1], reverse=True)

# %%
sorted_resume_similarities[:15]
# Out:
# [(1300, tensor(0.8923, device='cuda:0')),
#  (3614, tensor(0.8875, device='cuda:0')),
#  (3592, tensor(0.8870, device='cuda:0')),
#  (1062, tensor(0.8828, device='cuda:0')),
#  (2127, tensor(0.8828, device='cuda:0')),
#  (2195, tensor(0.8828, device='cuda:0')),
#  (4743, tensor(0.8805, device='cuda:0')),
#  (335, tensor(0.8801, device='cuda:0')),
#  (2894, tensor(0.8794, device='cuda:0')),
#  (779, tensor(0.8787, device='cuda:0')),
#  (3745, tensor(0.8753, device='cuda:0')),
#  (3013, tensor(0.8746, device='cuda:0')),
#  (4046, tensor(0.8746, device='cuda:0')),
#  (3829, tensor(0.8744, device='cuda:0')),
#  (237, tensor(0.8733, device='cuda:0'))]

# %%
sorted_df = df.iloc[[index for index, similarity in sorted_resume_similarities]]

sorted_df.head(15)
# Out:
#                                                Position      Sex   Age  \
# 1300                                Ведущий разработчик  Мужчина  39.0
# 3614       Программист ERP систем 1С / удаленная работа  Мужчина  47.0
# 3592                                      ИТ-специалист  Мужчина  36.0
# 1062                                     .NET Developer  Мужчина  35.0
# 2127                                     .NET Developer  Мужчина  35.0
# 2195                                     .NET Developer  Мужчина  35.0
# 4743                            Системный администратор  Мужчина  41.0
# 335                                         Разработчик  Мужчина  38.0
# 2894                                        Программист  Мужчина  54.0
# 779   Начальник IT-отдела, Зам Начальника Управления...  Мужчина  57.0
# 3745                                    Web-программист  Мужчина  48.0
# 3013  ИТ менеджер, специалист по работе с региональн...  Мужчина  59.0
# 4046  ИТ менеджер, специалист по работе с региональн...  Мужчина  59.0
# 3829                            Системный администратор  Мужчина  31.0
# 237   Директор по персоналу, Руководитель отдела пер...  Мужчина  38.0
#
#                 City  Is_Relocation_Ready  Is_Business_Trip_Ready  \
# 1300          Алматы                False                    True
# 3614         Щелково                False                    True
# 3592       Жуковский                False                    True
# 1062           Минск                False                    True
# 2127           Минск                False                    True
# 2195           Минск                False                    True
# 4743        Белгород                 True                   False
# 335           Москва                False                    True
# 2894           Химки                False                    True
# 779           Москва                False                    True
# 3745    Екатеринбург                 True                    True
# 3013          Москва                False                    True
# 4046          Москва                False                    True
# 3829  Ханты-Мансийск                False                    True
# 237           Алматы                 True                    True
#
#                                         Specializations  \
# 1300  Программист, разработчик, Архитектор, Руководи...
# 3614                           Программист, разработчик
# 3592                   Специалист технической поддержки
# 1062                           Программист, разработчик
# 2127                           Программист, разработчик
# 2195                           Программист, разработчик
# 4743  Системный администратор, Системный инженер, Сп...
# 335   Руководитель группы разработки, Программист, р...
# 2894                           Программист, разработчик
# 779                      Руководитель группы разработки
# 3745                           Программист, разработчик
# 3013          Специалист по информационной безопасности
# 4046          Специалист по информационной безопасности
# 3829  Сетевой инженер, Системный инженер, Директор п...
# 237   Директор по персоналу (HRD), Руководитель отде...
#
#                                              Employment  \
# 1300  полная занятость, частичная занятость, проектн...
# 3614                                   полная занятость
# 3592                 полная занятость, проектная работа
# 1062              полная занятость, частичная занятость
# 2127              полная занятость, частичная занятость
# 2195              полная занятость, частичная занятость
# 4743  полная занятость, частичная занятость, проектн...
# 335                                    полная занятость
# 2894  полная занятость, частичная занятость, проектн...
# 779                                    полная занятость
# 3745  полная занятость, частичная занятость, проектн...
# 3013                                   полная занятость
# 4046                                   полная занятость
# 3829              частичная занятость, проектная работа
# 237               полная занятость, частичная занятость
#
#                                           Work_Schedule  Desired_Salary  ...  \
# 1300  полный день, сменный график, гибкий график, уд...             NaN  ...
# 3614                                   удаленная работа        250000.0  ...
# 3592      полный день, сменный график, удаленная работа        120000.0  ...
# 1062       полный день, гибкий график, удаленная работа             NaN  ...
# 2127       полный день, гибкий график, удаленная работа             NaN  ...
# 2195       полный день, гибкий график, удаленная работа             NaN  ...
# 4743  полный день, сменный график, гибкий график, уд...         50000.0  ...
# 335                       полный день, удаленная работа             NaN  ...
# 2894  полный день, сменный график, гибкий график, уд...        120000.0  ...
# 779                                         полный день        160000.0  ...
# 3745  полный день, сменный график, гибкий график, уд...         50000.0  ...
# 3013                                        полный день        150000.0  ...
# 4046                                        полный день        150000.0  ...
# 3829                    гибкий график, удаленная работа         20000.0  ...
# 237        полный день, гибкий график, удаленная работа             NaN  ...
#
#                                                  Skills  \
# 1300  Cистемы управления базами данных, Joomla CMS, ...
# 3614                                        Обучаемость
# 3592  Информационные технологии, Техническая поддерж...
# 1062  C#, .NET Framework, WPF, Windows Forms, MS SQL...
# 2127  C#, .NET Framework, WPF, Windows Forms, MS SQL...
# 2195  C#, .NET Framework, WPF, Windows Forms, MS SQL...
# 4743  Сборка ПК, Ремонт ПК, Закупка оргтехники и обо...
# 335   XML, Visual Studio 2010/2012, Eclipse, Postgre...
# 2894  CAVO, Clipper, Crystal Reports, ADO, DAO, SOAP...
# 779   Банк-клиент, Средства криптографической защиты...
# 3745  Работоспособность, нацеленность на результат, ...
# 3013  Информационные технологии, Работа с ИТ подразд...
# 4046  Информационные технологии, Работа с ИТ подразд...
# 3829  Ремонт ПК, Работа с жалобами клиентов, Настрой...
# 237   1С: Управление персоналом, MS Excel, MS Outloo...
#
#                                              Languages  \
# 1300               Казахский - Родной, Английский - B1
# 3614                 Русский - Родной, Английский - B2
# 3592                 Русский - Родной, Английский - A1
# 1062                 Русский - Родной, Английский - B1
# 2127                 Русский - Родной, Английский - B1
# 2195                 Русский - Родной, Английский - B1
# 4743                 Русский - Родной, Английский - B2
# 335                  Русский - Родной, Английский - B2
# 2894                 Русский - Родной, Английский - A1
# 779   Русский - Родной, Английский - B2, Немецкий - B2
# 3745                 Русский - Родной, Английский - B2
# 3013                 Русский - Родной, Английский - C1
# 4046                 Русский - Родной, Английский - C1
# 3829                 Русский - Родной, Английский - B1
# 237                  Русский - Родной, Английский - C1
#
#                                               Education  \
# 1300  Алматинский институт энергетики и связи - Ради...
# 3614  Томский государственный архитектурно строитель...
# 3592  Московский энергетический институт, Москва - К...
# 1062  Филиал Компьютерной академии "ШАГ", Минск (Бел...
# 2127  Филиал Компьютерной академии "ШАГ", Минск (Бел...
# 2195  Филиал Компьютерной академии "ШАГ", Минск (Бел...
# 4743  Санкт-Петербургский государственный политехнич...
# 335   НИЯУ МИФИ(ТУ) - Экспериментальной и теоретичес...
# 2894  ХМТ (Химкинский механический техникум) - матем...
# 779   Московский авиационный институт государственны...
# 3745  Уральский государственный экономический универ...
# 3013  Высшее Военное Авиационное Училище Радиоэлектр...
# 4046  Высшее Военное Авиационное Училище Радиоэлектр...
# 3829  Московский государственный университет экономи...
# 237   Университет международного бизнеса, Алматы - M...
#
#                                                 Courses Has_Car  \
# 1300                                                NaN   False
# 3614  Учебный центр "Специалист" при МГТУ им. Н.Э. Б...   False
# 3592                                                NaN    True
# 1062                                                NaN   False
# 2127                                                NaN   False
# 2195                                                NaN   False
# 4743                                                NaN    True
# 335   Школа для одаренных детей с языковым уклоном "...   False
# 2894  Бухгалтерский учет на 1С8 Бухгалтерия - ЦЗ Хим...   False
# 779         infotecs - infotecs, пользователь ПО ViPNet    True
# 3745                                                NaN   False
# 3013  Курс английского языка "Banking communication"...   False
# 4046  Курс английского языка "Banking communication"...   False
# 3829  Ремонт и обслуживание ККМ - Аура г. Новосибирс...   False
# 237                                                 NaN   False
#
#      Driving_Categories                                           About_Me  \
# 1300                NaN  Разработка ПО, БД и СУБД. Внедрение, сопровожд...
# 3614                NaN  Имею комплексный подход к задачам, аналитическ...
# 3592                  B  Опыт администрирования и обеспечения работоспо...
# 1062                  B  Готов выполнить Ваше тестовое задание.\n\nУров...
# 2127                  B  Готов выполнить Ваше тестовое задание.\n\nУров...
# 2195                  B  Готов выполнить Ваше тестовое задание.\n\nУров...
# 4743                  B  **********************************************...
# 335                 NaN  - Практический опыт программирования более 5 л...
# 2894                NaN                                                NaN
# 779                   B  Операционные системы: DOS; SCO UNIX, SCO UnixW...
# 3745                NaN  Просьба не присылать задания, ищу работу, а не...
# 3013                  C  Работа с банковскими системами: «Диасофт 5NT»,...
# 4046                  C  Работа с банковскими системами: «Диасофт 5NT»,...
# 3829                NaN  Опыт развертывания инфраструктуры с ноля, обсл...
# 237                   B  Имею более 12 лет опыта работы в HR, в направл...
#
#               Job_Search_Status  \
# 1300  Предложили работу, решает
# 3614        Активно ищет работу
# 3592  Рассматривает предложения
# 1062        Активно ищет работу
# 2127        Активно ищет работу
# 2195        Активно ищет работу
# 4743        Активно ищет работу
# 335         Активно ищет работу
# 2894        Активно ищет работу
# 779   Рассматривает предложения
# 3745        Активно ищет работу
# 3013  Рассматривает предложения
# 4046  Рассматривает предложения
# 3829        Активно ищет работу
# 237   Рассматривает предложения
#
#                                                     URL  \
# 1300  https://spb.hh.ru/resume/8e7076e000015804ff003...
# 3614  https://spb.hh.ru/resume/75121359000178d9de003...
# 3592  https://spb.hh.ru/resume/48d3366d0004655d45003...
# 1062  https://spb.hh.ru/resume/c6ccc2af0003d07920003...
# 2127  https://spb.hh.ru/resume/c6ccc2af0003d07920003...
# 2195  https://spb.hh.ru/resume/c6ccc2af0003d07920003...
# 4743  https://spb.hh.ru/resume/438368430007bc6c43003...
# 335   https://spb.hh.ru/resume/153fd4a9000310ba3c003...
# 2894  https://spb.hh.ru/resume/2957c1610002544ad4003...
# 779   https://spb.hh.ru/resume/f85b8a3900049bcd54003...
# 3745  https://spb.hh.ru/resume/271fea1700044dcc84003...
# 3013  https://spb.hh.ru/resume/bdf26f2e00011a9c16003...
# 4046  https://spb.hh.ru/resume/bdf26f2e00011a9c16003...
# 3829  https://spb.hh.ru/resume/26d105130003021487003...
# 237   https://spb.hh.ru/resume/796a4d9f00020f801c003...
#
#                                              Embeddings
# 1300  [0.550189733505249, 0.298458456993103, -1.3737...
# 3614  [0.6192873120307922, 0.24165144562721252, -0.9...
# 3592  [0.3672751784324646, 0.21559642255306244, -1.0...
# 1062  [0.4485098123550415, 0.053186796605587006, -0....
# 2127  [0.4485098123550415, 0.053186796605587006, -0....
# 2195  [0.4485098123550415, 0.053186796605587006, -0....
# 4743  [0.17014414072036743, 0.26617586612701416, -0....
# 335   [0.39447101950645447, 0.212234228849411, -0.96...
# 2894  [0.5982185006141663, 0.32447218894958496, -1.0...
# 779   [0.34469497203826904, 0.2469232678413391, -1.0...
# 3745  [0.5555105209350586, 0.16347302496433258, -1.2...
# 3013  [0.16411441564559937, 0.27835339307785034, -1....
# 4046  [0.16411441564559937, 0.27835339307785034, -1....
# 3829  [0.18258008360862732, 0.26607224345207214, -0....
# 237   [0.29876744747161865, 0.424587607383728, -1.17...
#
# [15 rows x 22 columns]

# %%
assert len(df) == embeddings.shape[0]

# %%
embeddings.size()
embeddings_list = embeddings.cpu().numpy().tolist()  # Move embeddings back to CPU and convert to list

# Add embeddings as a new column in the DataFrame
df['Embeddings'] = embeddings_list

# %%
df.head()
# Out:
#                                             Position      Sex   Age  \
# 0                            Системный администратор  Мужчина  40.0
# 1                               Администратор-кассир  Женщина  22.0
# 2  Производственный руководитель, начальник участ...  Мужчина  38.0
# 3     Специалист по охране окружающей среды (эколог)  Женщина  33.0
# 4                          Оператор 1с, Товаровед 1с  Женщина  38.0
#
#             City  Is_Relocation_Ready  Is_Business_Trip_Ready  \
# 0        Колпино                False                    True
# 1   Екатеринбург                 True                    True
# 2         Москва                 True                    True
# 3  Новый Уренгой                 True                    True
# 4     Красноярск                False                   False
#
#                                      Specializations  \
# 0                            Системный администратор
# 1  Оператор ПК, оператор базы данных, Делопроизво...
# 2  Начальник производства, Начальник смены, масте...
# 3  Инженер по охране труда и технике безопасности...
# 4                  Оператор ПК, оператор базы данных
#
#                                           Employment  \
# 0              частичная занятость, проектная работа
# 1              полная занятость, частичная занятость
# 2  полная занятость, частичная занятость, проектн...
# 3              полная занятость, частичная занятость
# 4                                   полная занятость
#
#                                        Work_Schedule  Desired_Salary  ...  \
# 0    сменный график, гибкий график, удаленная работа             NaN  ...
# 1                      сменный график, гибкий график         45000.0  ...
# 2  полный день, сменный график, гибкий график, уд...             NaN  ...
# 3  полный день, сменный график, гибкий график, уд...             NaN  ...
# 4                                        полный день         50000.0  ...
#
#                                               Skills  \
# 0  Windows Server 2003/2008R2/2012R2 на уровне ад...
# 1  Пользователь Autocad, Arhicad, Пользователь wo...
# 2  Коммуникабельность, Мобильность, Пунктуальност...
# 3  Проведение тренинга для новых сотрудников, Орг...
# 4  1С: Торговля и склад, Складской Учет, ТТН, Вво...
#
#                                            Languages  \
# 0                  Русский - Родной, Английский - A1
# 1                                   Русский - Родной
# 2  Русский - Родной, Английский - A1, Китайский - A1
# 3                  Русский - Родной, Английский - B2
# 4                                   Русский - Родной
#
#                                            Education  \
# 0  Российский государственный гидрометеорологичес...
# 1  УКТП - Строительство и эксплуатация зданий и с...
# 2  Алма атинская Академия Бизнеса - Управление пе...
# 3  ООО Образовательный центр «Техноимпульс» - Упр...
# 4         Красноярский Монтажный колледж - Экономист
#
#                                              Courses Has_Car  \
# 0  Mikrotik MTCNA - SPW, Корпоративная IP-телефон...    True
# 1                                                NaN   False
# 2                                                NaN   False
# 3  Обеспечение экологической безопасности руковод...   False
# 4  ЧУП"ЭЛИТА СЕРВИС" - ЧУП"ЭЛИТА СЕРВИС", маникюр...   False
#
#   Driving_Categories                                           About_Me  \
# 0                  B  Сертификаты от Microsoft: MTA: Windows Server®...
# 1                NaN        Быстро учусь. Ответственно подхожу к работе
# 2                  B  Азартен в работе. Не приемлю полумер. Увлекаюс...
# 3                  B  Я трудолюбивый и ответственный человек, требов...
# 4                  B  Приятная внешность, коммуникабельная,ответстве...
#
#            Job_Search_Status  \
# 0  Рассматривает предложения
# 1        Активно ищет работу
# 2  Рассматривает предложения
# 3        Активно ищет работу
# 4        Активно ищет работу
#
#                                                  URL  \
# 0  https://spb.hh.ru/resume/12275fe400043bd2ee003...
# 1  https://spb.hh.ru/resume/c3ad30c90007195c21003...
# 2  https://spb.hh.ru/resume/9f3bb5f70001fae21e003...
# 3  https://spb.hh.ru/resume/c730fa57000435d95e003...
# 4  https://spb.hh.ru/resume/79b35d240000eb1a51003...
#
#                                           Embeddings
# 0  [0.32768160104751587, 0.08176106214523315, -0....
# 1  [0.345800518989563, 0.1473490446805954, -1.682...
# 2  [1.0071132183074951, 0.1831478774547577, -1.17...
# 3  [0.21396110951900482, 0.12703493237495422, -1....
# 4  [0.4720255434513092, 0.23111078143119812, -1.5...
#
# [5 rows x 22 columns]

# %%
df.to_csv('resume_data_n_embeddings.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-e02d8560b9bf> in <cell line: 1>()
# ----> 1 df.to_csv('resume_data_n_embeddings.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718         )
#    3719
# -> 3720         return DataFrameRenderer(formatter).to_csv(
#    3721             path_or_buf,
#    3722             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1187             formatter=self.fmt,
#    1188         )
# -> 1189         csv_formatter.save()
#    1190
#    1191         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     259             )
#     260
# --> 261             self._save()
#     262
#     263     def _save(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     264         if self._need_to_save_header:
#     265             self._save_header()
# --> 266         self._save_body()
#     267
#     268     def _save_header(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     302             if start_i >= end_i:
#     303                 break
# --> 304             self._save_chunk(start_i, end_i)
#     305
#     306     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     313
#     314         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 315         libwriters.write_csv_rows(
#     316             data,
#     317             ix,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
df.loc[1062]
# Out:
# Position                                                     .NET Developer
# Sex                                                                 Мужчина
# Age                                                                    35.0
# City                                                                  Минск
# Is_Relocation_Ready                                                   False
# Is_Business_Trip_Ready                                                 True
# Specializations                                    Программист, разработчик
# Employment                            полная занятость, частичная занятость
# Work_Schedule                  полный день, гибкий график, удаленная работа
# Desired_Salary                                                          NaN
# Total_Experience                                                      10.83
# Previous_Positions        Инженер-программист, Инженер-программист, Инже...
# Skills                    C#, .NET Framework, WPF, Windows Forms, MS SQL...
# Languages                                 Русский - Родной, Английский - B1
# Education                 Филиал Компьютерной академии "ШАГ", Минск (Бел...
# Courses                                                                 NaN
# Has_Car                                                               False
# Driving_Categories                                                        B
# About_Me                  Готов выполнить Ваше тестовое задание.\n\nУров...
# Job_Search_Status                                       Активно ищет работу
# URL                       https://spb.hh.ru/resume/c6ccc2af0003d07920003...
# Embeddings                [0.4485098123550415, 0.053186796605587006, -0....
# Name: 1062, dtype: object
